# %%
import numpy as np
import pandas as pd
import re
from nltk.corpus import stopwords
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]

# %%
fake_data = pd.read_csv('/content/Fake.csv')
true_data = pd.read_csv('/content/True.csv')

# %%
fake_data.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true_data.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake_data['label'] = 1
true_data['label'] = 0

# %%
news_data = pd.concat([fake_data, true_data], ignore_index=True)

# %%
news_data = news_data.sample(frac=1).reset_index(drop=True)

# %%
news_data
# Out:
#                                                    title  \
# 0      HILLARY SUPPORTER BRAGS About Looting “White B...
# 1       Libertarians Want Security Briefings – Maybe ...
# 2      MARIA BARTIROMO Gets Into Heated Interview Wit...
# 3       WATCH: New Clinton Ad Brilliantly Goes After ...
# 4      Factbox: What to watch for at China's Communis...
# ...                                                  ...
# 45734  HOW PRESIDENT TRUMP Can Remove Congress From T...
# 45735  Fugitive Italian 'cocaine king' arrested in Ur...
# 45736  U.S. senators vote to bolster travel security ...
# 45737   Samantha Bee BLASTS GOP Over ‘C*ckblocking’ O...
# 45738  U.S. will only talk to North Korea about freei...
#
#                                                     text       subject  \
# 0      In addition to be a disgusting criminal and an...     left-news
# 1      Libertarians are convinced that their presiden...          News
# 2      The DNC Chair Tom Perez took his delusional an...      politics
# 3      If you listen to Donald Trump at any of his ma...          News
# 4      BEIJING (Reuters) - China s ruling Communist P...     worldnews
# ...                                                  ...           ...
# 45734  President Trump tweeted that he was considerin...      politics
# 45735  ROME/MONTEVIDEO (Reuters) - One of Italy s mos...     worldnews
# 45736  WASHINGTON (Reuters) - The U.S. Senate voted o...  politicsNews
# 45737  Full Frontal host Samantha Bee is NOT one to m...          News
# 45738  WASHINGTON (Reuters) - The Trump administratio...     worldnews
#
#                      date  label
# 0            Aug 15, 2016      1
# 1      September 15, 2016      1
# 2             Nov 8, 2017      1
# 3            July 1, 2016      1
# 4       October 15, 2017       0
# ...                   ...    ...
# 45734        Jul 30, 2017      1
# 45735  September 4, 2017       0
# 45736      April 7, 2016       0
# 45737      March 22, 2016      1
# 45738    October 2, 2017       0
#
# [45739 rows x 5 columns]

# %%
 news_data.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
# merging title and author column
news_data['content'] = news_data['title']+' '+news_data['text']

# %%
news_data['content']
# Out:
# 0        HILLARY SUPPORTER BRAGS About Looting “White B...
# 1         Libertarians Want Security Briefings – Maybe ...
# 2        MARIA BARTIROMO Gets Into Heated Interview Wit...
# 3         WATCH: New Clinton Ad Brilliantly Goes After ...
# 4        Factbox: What to watch for at China's Communis...
#                                ...
# 45734    HOW PRESIDENT TRUMP Can Remove Congress From T...
# 45735    Fugitive Italian 'cocaine king' arrested in Ur...
# 45736    U.S. senators vote to bolster travel security ...
# 45737     Samantha Bee BLASTS GOP Over ‘C*ckblocking’ O...
# 45738    U.S. will only talk to North Korea about freei...
# Name: content, Length: 45739, dtype: object

# %%
news_data = news_data.drop(['subject'], axis=1)

# %%
news_data = news_data.drop(['date'], axis=1)

# %%
news_data
# Out:
#                                                    title  \
# 0      HILLARY SUPPORTER BRAGS About Looting “White B...
# 1       Libertarians Want Security Briefings – Maybe ...
# 2      MARIA BARTIROMO Gets Into Heated Interview Wit...
# 3       WATCH: New Clinton Ad Brilliantly Goes After ...
# 4      Factbox: What to watch for at China's Communis...
# ...                                                  ...
# 45734  HOW PRESIDENT TRUMP Can Remove Congress From T...
# 45735  Fugitive Italian 'cocaine king' arrested in Ur...
# 45736  U.S. senators vote to bolster travel security ...
# 45737   Samantha Bee BLASTS GOP Over ‘C*ckblocking’ O...
# 45738  U.S. will only talk to North Korea about freei...
#
#                                                     text  label  \
# 0      In addition to be a disgusting criminal and an...      1
# 1      Libertarians are convinced that their presiden...      1
# 2      The DNC Chair Tom Perez took his delusional an...      1
# 3      If you listen to Donald Trump at any of his ma...      1
# 4      BEIJING (Reuters) - China s ruling Communist P...      0
# ...                                                  ...    ...
# 45734  President Trump tweeted that he was considerin...      1
# 45735  ROME/MONTEVIDEO (Reuters) - One of Italy s mos...      0
# 45736  WASHINGTON (Reuters) - The U.S. Senate voted o...      0
# 45737  Full Frontal host Samantha Bee is NOT one to m...      1
# 45738  WASHINGTON (Reuters) - The Trump administratio...      0
#
#                                                  content
# 0      HILLARY SUPPORTER BRAGS About Looting “White B...
# 1       Libertarians Want Security Briefings – Maybe ...
# 2      MARIA BARTIROMO Gets Into Heated Interview Wit...
# 3       WATCH: New Clinton Ad Brilliantly Goes After ...
# 4      Factbox: What to watch for at China's Communis...
# ...                                                  ...
# 45734  HOW PRESIDENT TRUMP Can Remove Congress From T...
# 45735  Fugitive Italian 'cocaine king' arrested in Ur...
# 45736  U.S. senators vote to bolster travel security ...
# 45737   Samantha Bee BLASTS GOP Over ‘C*ckblocking’ O...
# 45738  U.S. will only talk to North Korea about freei...
#
# [45739 rows x 4 columns]

# %%
from nltk.stem import SnowballStemmer

stemmer = SnowballStemmer("english")

def stemming(content):
    stemmed_content = re.sub('[^a-zA-Z]', ' ', content)
    stemmed_content = stemmed_content.lower()
    stemmed_content = stemmed_content.split()
    stemmed_content = [stemmer.stem(word) for word in stemmed_content if word not in stopwords.words('english')]
    return ' '.join(stemmed_content)

# %%
# Apply the function
news_data['content'] = news_data['content'].apply(clean_and_stem)

# %%
print(news_data)
# Out:
#                                                    title  \
# 0      HILLARY SUPPORTER BRAGS About Looting “White B...
# 1       Libertarians Want Security Briefings – Maybe ...
# 2      MARIA BARTIROMO Gets Into Heated Interview Wit...
# 3       WATCH: New Clinton Ad Brilliantly Goes After ...
# 4      Factbox: What to watch for at China's Communis...
# ...                                                  ...
# 45734  HOW PRESIDENT TRUMP Can Remove Congress From T...
# 45735  Fugitive Italian 'cocaine king' arrested in Ur...
# 45736  U.S. senators vote to bolster travel security ...
# 45737   Samantha Bee BLASTS GOP Over ‘C*ckblocking’ O...
# 45738  U.S. will only talk to North Korea about freei...
#
#                                                     text  label  \
# 0      In addition to be a disgusting criminal and an...      1
# 1      Libertarians are convinced that their presiden...      1
# 2      The DNC Chair Tom Perez took his delusional an...      1
# 3      If you listen to Donald Trump at any of his ma...      1
# 4      BEIJING (Reuters) - China s ruling Communist P...      0
# ...                                                  ...    ...
# 45734  President Trump tweeted that he was considerin...      1
# 45735  ROME/MONTEVIDEO (Reuters) - One of Italy s mos...      0
# 45736  WASHINGTON (Reuters) - The U.S. Senate voted o...      0
# 45737  Full Frontal host Samantha Bee is NOT one to m...      1
# 45738  WASHINGTON (Reuters) - The Trump administratio...      0
#
#                                                  content
# 0      hillari support brag loot “white businesses” m...
# 1      libertarian want secur brief – mayb gari johns...
# 2      maria bartiromo get heat interview dnc chair t...
# 3      watch new clinton ad brilliant goe trump produ...
# 4      factbox watch china communist parti congress b...
# ...                                                  ...
# 45734  presid trump remov congress obamacar exempt vi...
# 45735  fugit italian cocain king arrest uruguay romem...
# 45736  us senat vote bolster travel secur faa bill wa...
# 45737  samantha bee blast gop cckblock obama scotus n...
# 45738  us talk north korea free us citizen white hous...
#
# [45739 rows x 4 columns]

# %%
x = news_data['content'].values
y = news_data['label'].values

# %%
print(x)
print(y)
# Out:
# ['hillari support brag loot “white businesses” milwaukee…honor hillari equal opportun card…br sister along video addit disgust crimin idiot jerom also hillari support twitter account clear show besid open crimin racist also hillari support bio show support blacklivesmatt hillari imwithherjayrom william also tweet support hillaryher jayrom damn autocorrect keep tri make name jerom brag go loot busi take advantag cri riot death arm black man run polic refus drop stolen gun specif mention white own busi gonna loot jayrom brag loot got hard night work steal white own busi jayrom brag bring sister along loot true hillari support will give sister opportun steal white man would retweet hillari support jayrom william wonder support hillari want take gun hand legal gun owner leav thug gun dont send threat gang aint war caus strap gun yall cant afford forgi jayforgi august'
#  'libertarian want secur brief – mayb gari johnson would know aleppo libertarian convinc presidenti ticket get secur brief like democrat republican seem think possibl scenario could come top novemberdonald trump hillari clinton began receiv secur brief short offici becam nomine respect parti appar poor gari johnson feel left outeven though uncommon third parti candid get kind brief first last third parti candid receiv secur brief john anderson independ libertarian parti think johnson run mate former massachusett gov bill weld elig receiv secur brief toolibertarian nation chairman nichola sarwark wrote letter general servic administr gsa thursday argu libertarian candid get nation secur brief sinc ballot state even feder govern busi attempt preselect voter choic presid vicepresid three ticket ballot state district columbia two receiv taxpayerfund nation secur brief wrong urg gsa provid inform governor johnson given mr trump sec clinton presidenti transit act make presidenti candid abl receiv secur brief includ third parti candid howev law also say candid must signific level public support nation poll need realist thought chanc win presidencyeven though johnson name ballot state poll percent enough public support get onto debat stage let alon white hous sure realist possibl johnson presid actual ison hand perhap nation secur brief two would good johnson mayb could tell heck aleppo isfeatur imag via georg freygetti imag'
#  'maria bartiromo get heat interview dnc chair tom perez “your parti hijack extrem left” video dnc chair tom perez took delusion nasti attitud fox busi morn maria bartiromo let dose brutal truth direct dem go parti hijack extrem left barack obama elizabeth warren thing got fair normal start bartiromo ask dnc chairman parti victori tuesday elect bartiromo hit nerv mention accus clinton fix primaryperez shot back maria understand democrat win across board last night would like focus thing perez tout obamacar bartiromo said health care system implod two went back forth perez attempt defend afford care act bartiromo grill whether spoken sander sinc brazil revelationsbartiromo kept come back perez truth bomb somebodi owe berni sander phone call sinc know took place everyth rig behind hillari clinton charg maria know lectur qa tell perez lament ask perez dnc turn comput fbi investig repli maria fiction wonderland right perez tri turn convers back tuesday elect result claim proof voter embrac democrat visionbest line interview heard vision bartiromo shout back parti hijack extrem left barack obama elizabeth warren read mediait'
#  ...
#  'us senat vote bolster travel secur faa bill washington reuter us senat vote thursday bolster travel secur wake brussel attack measur includ doubl number transport secur team bombsnif dog domest airport transit hub lawmak vote overwhelm add secur measur separ bill call renew program feder aviat administr septemb faa bill expect come final vote later month republican democrat reach deal secur measur earlier day lawmak vote rais number visibl intermod prevent respons viper team within transport secur administr viper team intend visibl deterr attack deploy airport train bus station measur would bolster vet airport employe add secur vulner checkin baggag claim area author tsa donat secur equip foreign airport direct flight unit state approv provis would also order new us assess foreign cargo secur program provid grant money train state local foreign author respond masscasualti “activ shooter” incid unclear kind recept faa bill pass senat might receiv hous repres hous lawmak consid faa legisl bill also call privat us air traffic control system measur senat legisl'
#  'samantha bee blast gop cckblock obama scotus nomine video full frontal host samantha bee one minc word took gop woodsh latest episod show refus even consid presid obama nomine replac deceas justic antonin scalia suprem court worst part blatant ploy keep highest court land tip favor conserv definit nomine merrick garland even liber centrist grant rule common sens flame bigot gop standard make left berni sandersbe rail say cckblock gentl law hobbit went take halfmelt reagan dummi madam tussaud wax museum ted cruz well goper task refer presid obama lame duck bee said jesus christ lame duck three trimest away lame duckeri presid term four year say three legitim fourth garbag indiana jone movi final hilari host point huge gambl either go garland wait hillari clinton nomin transgend black panther abort doctor donald trump go pile maxim magazin either way lose bigbe beyond right cours gop play polit tri take presid obama right duti job last year offic away goddammit gop senat stop act like babi doyourjobwatch video via crook liarsfeatur imag via video screen captur'
#  'us talk north korea free us citizen white hous washington reuter trump administr hold talk north korea time except possibl convers free us citizen detain white hous said monday clear time talk white hous spokeswoman sarah sander told report amplifi tweet presid donald trump weekend seen undercut us secretari state rex tillerson convers taken place would would bring back american detain sander said beyond convers north korea time']
# [1 1 1 ... 0 1 0]

# %%
y.shape
# Out:
# (45739,)

# %%
# converting textual data into numerical data
vectorizer = TfidfVectorizer(
    stop_words='english',
    max_features=10000
)
x = vectorizer.fit_transform(x)

# %%
print(x)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 5920804 stored elements and shape (45739, 10000)>
#   Coords	Values
#   (0, 4090)	0.3211151000864323
#   (0, 8652)	0.2555310673995522
#   (0, 1071)	0.303251798695266
#   (0, 5221)	0.4745730761123932
#   (0, 9765)	0.1409640012344703
#   (0, 4158)	0.06611880311045634
#   (0, 2942)	0.06465034270591559
#   (0, 6204)	0.11877726845886588
#   (0, 1332)	0.0726958785863122
#   (0, 8116)	0.23604714727579543
#   (0, 9548)	0.0347578752008041
#   (0, 89)	0.0547401616274891
#   (0, 2521)	0.0691885829834871
#   (0, 2058)	0.10832952358933326
#   (0, 4278)	0.07697384373315252
#   (0, 4683)	0.22164648884503457
#   (0, 9201)	0.04699011198781139
#   (0, 57)	0.05061906672429856
#   (0, 1616)	0.04020284197289747
#   (0, 858)	0.08019918548931312
#   (0, 6196)	0.0432588864450473
#   (0, 7059)	0.05756005646239268
#   (0, 931)	0.09524561611024045
#   (0, 9800)	0.14134866883831393
#   (0, 9194)	0.049535515378227785
#   :	:
#   (45738, 2620)	0.05405954697478213
#   (45738, 8756)	0.2321703897790139
#   (45738, 7427)	0.04902598749943947
#   (45738, 7852)	0.08589051664083383
#   (45738, 7346)	0.05907057861022897
#   (45738, 8964)	0.17100615338609246
#   (45738, 8748)	0.09668411943324558
#   (45738, 9673)	0.06629081172202332
#   (45738, 8993)	0.059112683599897894
#   (45738, 306)	0.06593679846664188
#   (45738, 5732)	0.08293044496204294
#   (45738, 4124)	0.08892724151609721
#   (45738, 1574)	0.20297472821371426
#   (45738, 2383)	0.2734621764050879
#   (45738, 9719)	0.12475548266330957
#   (45738, 3480)	0.19501630022535496
#   (45738, 7866)	0.09141612426577514
#   (45738, 6044)	0.2862167860274363
#   (45738, 4904)	0.35045149106423507
#   (45738, 7723)	0.14395350700277
#   (45738, 8352)	0.118756558019559
#   (45738, 7452)	0.13893031610816273
#   (45738, 8960)	0.13844663812008678
#   (45738, 9280)	0.1894562924125938
#   (45738, 318)	0.19854088948377333

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2,stratify=y, random_state=3)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (45739, 10000) (36591, 10000) (9148, 10000)

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
# training data accuracy score
x_train_pred = model.predict(x_train)
train_data_accuracy = accuracy_score(x_train_pred, y_train)

# testing data accuracy score
x_test_pred = model.predict(x_test)
test_data_accuracy = accuracy_score(x_test_pred, y_test)

# result
print(f"Accuracy score of training data: {train_data_accuracy:.2f}")
print(f"Accuracy score of testing data: {test_data_accuracy:.2f}")
# Out:
# Accuracy score of training data: 0.99
# Accuracy score of testing data: 0.99

# %%
print(x_test)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1192555 stored elements and shape (9148, 10000)>
#   Coords	Values
#   (0, 4390)	0.08985761409361372
#   (0, 3734)	0.2264160024354978
#   (0, 573)	0.08509016326284527
#   (0, 76)	0.07668322826453189
#   (0, 7749)	0.04359092535807261
#   (0, 7661)	0.06750006050897699
#   (0, 7481)	0.05998539296445679
#   (0, 7427)	0.044219009503693396
#   (0, 7610)	0.2260440156135236
#   (0, 1994)	0.11268834873507412
#   (0, 1426)	0.19828626081924788
#   (0, 5493)	0.18940460598615172
#   (0, 6636)	0.06739569716396207
#   (0, 7237)	0.2536177162029586
#   (0, 8348)	0.17153565294001857
#   (0, 9611)	0.06751625848940351
#   (0, 4291)	0.09031616983794542
#   (0, 9746)	0.11965590222946676
#   (0, 4124)	0.16041592381112157
#   (0, 7256)	0.17884132498924704
#   (0, 1598)	0.12719076552380357
#   (0, 7393)	0.21446881693642844
#   (0, 422)	0.09036528978698395
#   (0, 3012)	0.09475227440379884
#   (0, 3501)	0.07381635497353352
#   :	:
#   (9147, 2840)	0.04246110174138328
#   (9147, 6410)	0.0606196060127129
#   (9147, 895)	0.05898023214306461
#   (9147, 2423)	0.054796207353351334
#   (9147, 9078)	0.05639201957505134
#   (9147, 2258)	0.09766263554033684
#   (9147, 4922)	0.06529045194654007
#   (9147, 1999)	0.11442146788875368
#   (9147, 1620)	0.13138342261496122
#   (9147, 7286)	0.06911478720440524
#   (9147, 741)	0.07143470706426891
#   (9147, 4609)	0.066461608972062
#   (9147, 5898)	0.05333365122339206
#   (9147, 7404)	0.059576930621350076
#   (9147, 3185)	0.06134166870011849
#   (9147, 903)	0.08233302006046445
#   (9147, 6219)	0.0656546138172575
#   (9147, 9950)	0.24598169563380412
#   (9147, 9050)	0.07162563877017143
#   (9147, 6628)	0.0749852961049464
#   (9147, 1882)	0.07052740958575765
#   (9147, 9456)	0.06979812708520497
#   (9147, 3005)	0.07414371129135891
#   (9147, 3853)	0.15032347820690212
#   (9147, 3248)	0.07534109864687885

# %%
print(x.shape)  # should be (num_samples, num_features)
print(vectorizer.get_feature_names_out()[:10])  # sample features
# Out:
# (45739, 10000)
# ['aaplo' 'aaron' 'aba' 'abadi' 'abandon' 'abba' 'abbasi' 'abbott' 'abc'
#  'abcpolit']

# %%
news_data['label'].value_counts()
# Out:
# label
# 1    23850
# 0    21889
# Name: count, dtype: int64

# %% [markdown]
# # Making predictive system

# %%
x_new = x_test[111]

prediction = model.predict(x_new)
print(prediction)

if prediction[0] == 0:
  print('The news is real')
else:
  print('The news is fake')
# Out:
# [1]
# The news is fake

# %%
print(y_test[111])
# Out:
# 1

# %%
user_input = input("Enter the news: ")
user_input_stemmed = stemming(user_input)
user_input_vectorized = vectorizer.transform([user_input_stemmed])
prediction = model.predict(user_input_vectorized)

if prediction[0] == 0:
  print('The news is real')
else:
  print('The news is fake')
# Out:
# Enter the news: Donald Trump spent a good portion of his day at his golf club, marking the 84th day he s done so since taking the oath of office. It must have been a bad game because just after that, Trump lashed out at FBI Deputy Director Andrew McCabe on Twitter following a report saying McCabe plans to retire in a few months. The report follows McCabe s testimony in front of congressional committees this week, as well as mounting criticism from Republicans regarding the Russia probe.So, naturally, Trump attacked McCabe with a lie. How can FBI Deputy Director Andrew McCabe, the man in charge, along with leakin  James Comey, of the Phony Hillary Clinton investigation (including her 33,000 illegally deleted emails) be given $700,000 for wife s campaign by Clinton Puppets during investigation?  Trump tweeted.How can FBI Deputy Director Andrew McCabe, the man in charge, along with leakin  James Comey, of the Phony Hillary Clinton investigation (including her 33,000 illegally deleted emails) be given $700,000 for wife s campaign by Clinton Puppets during investigation?  Donald J. Trump (@realDonaldTrump) December 23, 2017He didn t stop there.FBI Deputy Director Andrew McCabe is racing the clock to retire with full benefits. 90 days to go?!!!  Donald J. Trump (@realDonaldTrump) December 23, 2017Wow,  FBI lawyer James Baker reassigned,  according to @FoxNews.  Donald J. Trump (@realDonaldTrump) December 23, 2017With all of the Intel at Trump s disposal, he s getting his information from Fox News. McCabe spent most of his career in the fight against terrorism and now he s being attacked by the so-called president. Trump has been fact-checked before on his claim of his wife receiving $700,000 for her campaign.Politifact noted in late July that Trump s  tweet about Andrew McCabe is a significant distortion of the facts. And the implication that McCabe got Clinton off as a political favor doesn t make much sense when we look at the evidence. His July tweet was rated  mostly false.  But Trump repeats these lies because he knows his supporters will believe them without bothering to Google. It s still a lie, though.Photo by Zach Gibson   Pool/Getty Images.
# The news is fake

# %% [markdown]
# # Deployment on Streamlit

# %%
import pickle

# %%
file_name = 'model_news.sav'
pickle.dump(model, open(file_name, 'wb'))

# %%
with open("feature_extraction.pkl", "wb") as f:
    pickle.dump(vectorizer, f)
